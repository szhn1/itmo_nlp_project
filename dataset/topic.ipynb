# %%
import pandas as pd

feat = pd.read_parquet("../data/dataset_tg_economic.parquet")
feat.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                            message_id  views_o0  \
# 0             0           0  00027151-a524-4d93-a820-116398fb81bb  492127.0
# 1             1           2  0003b835-cf4a-43ff-b155-a144cf56b7f8  486195.0
# 2             2           4  0005535a-74a9-4cb9-853f-ce04612d2f94  455967.0
# 3             3           7  0007e2f8-787d-404f-91ff-e2582096a4a7   22376.0
# 4             4           8  000884a5-8291-4ec1-805f-ac131112aaf7   19493.0
#
#    views_o1  views_o2  views_o3  forwards_o0  forwards_o1  forwards_o2  ...  \
# 0  603269.0  619397.0  625475.0        381.0        415.0        449.0  ...
# 1  507393.0  514469.0  517508.0        273.0        273.0        273.0  ...
# 2  609468.0  627631.0  634731.0        448.0        551.0        551.0  ...
# 3   23594.0   23735.0   23825.0          5.0          9.0          9.0  ...
# 4   20605.0       NaN       NaN         64.0         67.0          NaN  ...
#
#    best_ctr_reactions_0_3  viral_ml  viral_final  \
# 0                     NaN -0.173209     0.406649
# 1                     NaN -0.150123     0.445509
# 2                     NaN -0.170353     0.396754
# 3                     NaN  0.005396     0.703622
# 4                 0.00041  0.024601     0.680369
#
#                                             llm_json  is_economic  \
# 0  {'confidence': 0.96, 'economic_signals': array...        False
# 1  {'confidence': 0.9, 'economic_signals': array(...        False
# 2  {'confidence': 0.95, 'economic_signals': array...        False
# 3  {'confidence': 0.96, 'economic_signals': array...         True
# 4  {'confidence': 0.96, 'economic_signals': array...         True
#
#                    topic  confidence  \
# 0                   None        0.96
# 1                   None        0.90
# 2                   None        0.95
# 3  Санкции и геополитика        0.96
# 4         Рынки капитала        0.96
#
#                                               reason  economic_signals  \
# 0  Текст содержит лишь политические и военные выс...               NaN
# 1  Новость посвящена уголовному делу о хищении ср...               NaN
# 2  Новость описывает процесс поступления детей в ...               NaN
# 3  Новость посвящена позиции Сербии по санкциям Е...               NaN
# 4  Новость описывает падение фондового рынка и ра...               NaN
#
#   noise_signals
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 95 columns]

# %%
df = feat[['message_id', 'id_channel', 'message', 'viral_final']]
df.head()
# Out:
#                              message_id  id_channel  \
# 0  00027151-a524-4d93-a820-116398fb81bb           3
# 1  0003b835-cf4a-43ff-b155-a144cf56b7f8           3
# 2  0005535a-74a9-4cb9-853f-ce04612d2f94           3
# 3  0007e2f8-787d-404f-91ff-e2582096a4a7          18
# 4  000884a5-8291-4ec1-805f-ac131112aaf7           6
#
#                                              message  viral_final
# 0  Европа делает "самоубийственное движение", ког...     0.406649
# 1  Верховный суд Ингушетии отправил под арест быв...     0.445509
# 2  Свыше миллиона детей пойдут в первый класс в э...     0.396754
# 3  Сербия согласна поддержать санкции Евросоюза п...     0.703622
# 4  Китайский рынок акций упал сильнее всего с апр...     0.680369

# %%
df.shape
# Out:
# (67255, 4)

# %%
prompt = """
Ты — разметчик новостей для исследования экономических нарративов.

ЗАДАЧА
По тексту ОДНОЙ новости:
1) определить, относится ли она к экономике (is_economic)
2) если is_economic=true — присвоить ровно ОДИН тематический класс topic из списка ниже

СПИСОК КЛАССОВ (topic)
Ровно один из:
- "Макроэкономика"
- "Рынки капитала"
- "Корпоративные финансы"
- "Санкции и геополитика"
- "Сырьевые рынки"
- "Валютный рынок"
- "Государственная экономическая политика"
- "Международная торговля"
- "Другое"

ОПРЕДЕЛЕНИЕ “ЭКОНОМИЧЕСКОЙ” НОВОСТИ
Считай новость экономической (is_economic=true), если в ней есть СУЩЕСТВЕННОЕ содержание хотя бы по одному из пунктов:
- Макроэкономика и состояние экономики: инфляция, ВВП, безработица, бюджет/дефицит, доходы населения, цены, промышленность, потребление и т.п.
- Финансы/банки/кредит/ипотека/процентные ставки, решения ЦБ/регуляторов, финансовое регулирование.
- Валюты и курсы: рубль/доллар/евро и др., валютные ограничения.
- Рынки капитала: акции, облигации, индексы, доходности, биржи, IPO.
- Корпоративные финансы: отчётность, прибыль/убыток, дивиденды, M&A, банкротства.
- Сырьевые рынки: нефть/газ/уголь/металлы/зерно и др. как рынок (цены, спрос/предложение, поставки, квоты).
- Санкции/геополитика — ТОЛЬКО если явно есть экономическое измерение (финансовые ограничения, экспорт/импорт, цены, дефицит, рынки, бюджет, цепочки поставок).
- Государственная экономическая политика: налоги, пошлины, тарифы, субсидии, госпрограммы, бюджетные решения, регулирование цен/рынков.
- Международная торговля: экспорт/импорт, таможня, квоты, торговые соглашения, логистика поставок как фактор торговли.

Считай новость НЕ экономической (is_economic=false), если:
- Основной смысл — развлечения/мемы/погода/гороскоп/спорт/культура/криминал без экономического измерения.
- Реклама/промо/розыгрыши/подписки/букмекерские ставки и т.п. (даже если встречается слово “ставка”, но в спортивном/промо-контексте).

ПРАВИЛО “СУЩЕСТВЕННОСТИ”
- Если деньги/цены/зарплаты упомянуты вскользь и без фактов/мер/последствий/контекста — чаще is_economic=false.
- Если есть факты, меры, последствия, цифры, решения регуляторов, влияние на рынки/торговлю/бюджет — is_economic=true.

КАК ВЫБИРАТЬ topic (ТОЛЬКО ЕСЛИ is_economic=true)
Выбери самый “главный” фокус новости. Если упоминается несколько тем, выбирай по приоритету:
(1) конкретное решение/событие, которое является ядром новости
(2) то, чему посвящено больше всего текста/фактов/цифр
(3) то, что описывает основной механизм влияния (например, через валютный курс или санкции)

КРАТКИЕ КРИТЕРИИ КЛАССОВ
- "Макроэкономика": инфляция, ВВП, безработица, рост/рецессия, индекс деловой активности, общие показатели экономики.
- "Рынки капитала": акции/облигации/индексы/биржи/доходности/IPO, движение котировок, размещения.
- "Корпоративные финансы": финрезультаты компаний, дивиденды, сделки M&A, банкротства, долговая нагрузка компаний.
- "Санкции и геополитика": санкции/ограничения/конфискации/эмбарго/политические решения с явным экономическим эффектом (финансы, торговля, рынки, бюджет, цепочки поставок).
- "Сырьевые рынки": нефть/газ/металлы/зерно и др. — цены, добыча, поставки, OPEC, экспорт сырья как рынок.
- "Валютный рынок": курсы валют, интервенции, валютный контроль, FX-ликвидность, привязки/коридоры.
- "Государственная экономическая политика": налоги, пошлины, тарифы, субсидии, регулирование, бюджетные меры, госпрограммы, госрасходы.
- "Международная торговля": экспорт/импорт, торговые соглашения, квоты, таможенные меры, торговые потоки и логистика как фактор торговли.
- "Другое": экономическая новость, но не укладывается уверенно в классы выше (например, рынок труда в узком секторе без макрофокуса, потребительские тренды без макро-метрик, технологические/отраслевые сюжеты без явного попадания в классы и т.п.).

ОБЯЗАТЕЛЬНОЕ ПРАВИЛО
Если is_economic=false, то topic должен быть null.

ВЫХОД (СТРОГО JSON, БЕЗ ЛИШНЕГО ТЕКСТА)
Верни только JSON:

{
  "is_economic": true/false,
  "topic": "один из классов выше" или null,
  "confidence": 0.0,
  "reason": "1-2 коротких предложения: почему так",
  "economic_signals": ["2-6 ключевых сигналов/терминов из текста (если is_economic=true)"],
  "noise_signals": ["1-4 сигнала шума (если применимо)"]
}

ШКАЛА confidence
- 0.9–1.0: очевидно
- 0.6–0.8: экономическое есть, но не центральное / тема смешанная, но класс выбирается уверенно
- 0.4–0.5: погранично

ВХОД
Текст новости:
<<<{news_text}>>>
"""

# %%
df = df.rename(columns={'message':'query'})
df.head()
# Out:
#                              message_id  id_channel  \
# 0  00027151-a524-4d93-a820-116398fb81bb           3
# 1  0003b835-cf4a-43ff-b155-a144cf56b7f8           3
# 2  0005535a-74a9-4cb9-853f-ce04612d2f94           3
# 3  00064231-2c13-48f7-8f07-9abf2b049b89           1
# 4  0006e10d-39d5-48fd-b5d8-3fbc732d09f4           6
#
#                                                query  viral_final
# 0  Европа делает "самоубийственное движение", ког...     0.468767
# 1  Верховный суд Ингушетии отправил под арест быв...     0.428130
# 2  Свыше миллиона детей пойдут в первый класс в э...     0.456934
# 3  ❗️Бывший президент Сирии Башар Асад накануне с...     0.666604
# 4  Сегодня на рынке жилья сложилась патовая ситуа...     0.746281

# %%
import importlib
import labeling.llm_labeling_pipeline as llmp

importlib.reload(llmp)

from labeling.llm_labeling_pipeline import LlmLabelingConfig, LlmLabelingPipeline

display(df.head())

from datetime import datetime
run_tag = datetime.now().strftime("%Y%m%d_%H%M%S")

cfg = LlmLabelingConfig(
    text_col="query",
    bucket="ecom-ml-dolyame-search",
    prefix=f"labeling_tmp/tmp_artem/{run_tag}",
    endpoint_url="https://s3-msk.tinkoff.ru",
    access_key="1cadc5010397d9d83d85",
    secret_key="nTCjXZk87nahL4989I+/vUT+peNW56jYxHQIGesd",
    helpers_path="labeling", 
    tmp_root=None,                
    cleanup_tmp=False,
    chunk_size=35000,            
    flavor="4cpu-64ram",
    region="ix-m5-sm11",
    gpu_num=2,
    max_parallel=2,
    mlc_project="ecom-ml",
    system_prompt=prompt,
    as_json=True,
    template_name=".ml-job-preset.yml"
)

pipeline = LlmLabelingPipeline(cfg, input_df=df)

out_path, labeled_df = pipeline.run(save_merged=True)

print("Merged parquet:", out_path)
labeled_df.head()
# Out:
#                              message_id  id_channel  \
# 0  00027151-a524-4d93-a820-116398fb81bb           3
# 1  0003b835-cf4a-43ff-b155-a144cf56b7f8           3
# 2  0005535a-74a9-4cb9-853f-ce04612d2f94           3
# 3  00064231-2c13-48f7-8f07-9abf2b049b89           1
# 4  0006e10d-39d5-48fd-b5d8-3fbc732d09f4           6
#
#                                                query  viral_final
# 0  Европа делает "самоубийственное движение", ког...     0.468767
# 1  Верховный суд Ингушетии отправил под арест быв...     0.428130
# 2  Свыше миллиона детей пойдут в первый класс в э...     0.456934
# 3  ❗️Бывший президент Сирии Башар Асад накануне с...     0.666604
# 4  Сегодня на рынке жилья сложилась патовая ситуа...     0.746281
# [INIT] tmp_root = /workdir/project/tmp_files_run_20251217_000712
# [INIT] helpers_path = /workdir/project/labeling
# [PROMPT] updated SYSTEM_PROMPT in /workdir/project/labeling/system_prompt.py
# [LOAD] using in-memory DataFrame
# [LOAD] shape raw = (67255, 4)
# [LOAD] shape after dedup[query] = (66981, 4)
# [LOAD] N unique texts = 66981, chunk_size = 35000, num_chunks = 2
# [CHUNKS] writing & uploading 2 chunks...
# [CHUNKS] [chunk 0] 35000 rows -> /workdir/project/tmp_files_run_20251217_000712/data/data_0/data_for_labeling_0_dedup.csv
# [UPLOAD] s3://ecom-ml-dolyame-search/labeling_tmp/tmp_artem/20251217_000712/data_for_labeling_0_dedup.csv
# [CHUNKS] [chunk 1] 31981 rows -> /workdir/project/tmp_files_run_20251217_000712/data/data_1/data_for_labeling_1_dedup.csv
# [UPLOAD] s3://ecom-ml-dolyame-search/labeling_tmp/tmp_artem/20251217_000712/data_for_labeling_1_dedup.csv
# [RUN_DIRS] preparing in /workdir/project/tmp_files_run_20251217_000712/runs
# [RUN_DIRS] +folder: /workdir/project/tmp_files_run_20251217_000712/runs/0
# [RUN_DIRS] copy /workdir/project/labeling/llm_labeling.py -> /workdir/project/tmp_files_run_20251217_000712/runs/0/llm_labeling.py
# [RUN_DIRS] copy /workdir/project/labeling/config.yaml -> /workdir/project/tmp_files_run_20251217_000712/runs/0/config.yaml
# [RUN_DIRS] copy /workdir/project/labeling/.ml-job-preset.yml -> /workdir/project/tmp_files_run_20251217_000712/runs/0/.ml-job-preset.yml
# [RUN_DIRS] copy /workdir/project/labeling/system_prompt.py -> /workdir/project/tmp_files_run_20251217_000712/runs/0/system_prompt.py
# [RUN_DIRS] patched /workdir/project/tmp_files_run_20251217_000712/runs/0/config.yaml with: as_json: true
# [RUN_DIRS] preset: /workdir/project/tmp_files_run_20251217_000712/runs/0/.ml-job-preset.yml
# [RUN_DIRS] +folder: /workdir/project/tmp_files_run_20251217_000712/runs/1
# [RUN_DIRS] copy /workdir/project/labeling/llm_labeling.py -> /workdir/project/tmp_files_run_20251217_000712/runs/1/llm_labeling.py
# [RUN_DIRS] copy /workdir/project/labeling/config.yaml -> /workdir/project/tmp_files_run_20251217_000712/runs/1/config.yaml
# [RUN_DIRS] copy /workdir/project/labeling/.ml-job-preset.yml -> /workdir/project/tmp_files_run_20251217_000712/runs/1/.ml-job-preset.yml
# [RUN_DIRS] copy /workdir/project/labeling/system_prompt.py -> /workdir/project/tmp_files_run_20251217_000712/runs/1/system_prompt.py
# [RUN_DIRS] patched /workdir/project/tmp_files_run_20251217_000712/runs/1/config.yaml with: as_json: true
# [RUN_DIRS] preset: /workdir/project/tmp_files_run_20251217_000712/runs/1/.ml-job-preset.yml
# [MLC] submitting 2 jobs, max_parallel=2
# [MLC] start key=0
# [MLC] start key=1
# [MLC] done  key=1, code=0
#
# [MLC][stdout key=1]
# INFO mlc: load preset file .ml-job-preset.yml
# INFO mlc: Flavor 'a100-2x' has been changed to 'h100-2x' (GPU=2, CPU=28, RAM=286720Mb) in llm container
# INFO mlc: Job search_llm_labeling_1-i8rse4 created at 2025-12-16 21:07:15.156309 +0000 UTC
# INFO mlc: Streaming logs...
#
# unknown: [ML Core] Job is trying to free resources in the cluster...
# unknown: [ML Core] Job is trying to free resources in the clu ...
# [MLC] done  key=0, code=0
#
# [MLC][stdout key=0]
# INFO mlc: load preset file .ml-job-preset.yml
# INFO mlc: Flavor 'a100-2x' has been changed to 'h100-2x' (GPU=2, CPU=28, RAM=286720Mb) in llm container
# INFO mlc: Job search_llm_labeling_0-xz6x5w created at 2025-12-16 21:07:15.126515 +0000 UTC
# INFO mlc: Streaming logs...
#
# unknown: [ML Core] Job is trying to free resources in the cluster...
# unknown: [ML Core] Job is trying to free resources in the clu ...
#
# [MLC] summary:
#   key=0: code=0
#   key=1: code=0
# [RESULT] downloading outputs...
#
# [RESULT] key=0: 1 parquet(s)
#   2025-12-16T22:49:44.890000+00:00  23142928  s3://ecom-ml-dolyame-search/labeling_tmp/tmp_artem/20251217_000712/output_0/chunk_0_2025_12_16_22_49_labeled.parquet
# [RESULT] downloaded latest for key=0 -> /workdir/project/tmp_files_run_20251217_000712/data/data_0/chunk_0_2025_12_16_22_49_labeled.parquet
#
# [RESULT] key=1: 1 parquet(s)
#   2025-12-16T22:47:51.102000+00:00  21455006  s3://ecom-ml-dolyame-search/labeling_tmp/tmp_artem/20251217_000712/output_1/chunk_1_2025_12_16_22_47_labeled.parquet
# [RESULT] downloaded latest for key=1 -> /workdir/project/tmp_files_run_20251217_000712/data/data_1/chunk_1_2025_12_16_22_47_labeled.parquet
#
# [RESULT] merged parquet saved to: /workdir/project/tmp_files_run_20251217_000712/labeled_all.parquet (shape=(67255, 6))
# Merged parquet: /workdir/project/tmp_files_run_20251217_000712/labeled_all.parquet
#                              message_id  id_channel  \
# 0  00027151-a524-4d93-a820-116398fb81bb           3
# 1  0003b835-cf4a-43ff-b155-a144cf56b7f8           3
# 2  0005535a-74a9-4cb9-853f-ce04612d2f94           3
# 3  00064231-2c13-48f7-8f07-9abf2b049b89           1
# 4  0006e10d-39d5-48fd-b5d8-3fbc732d09f4           6
#
#                                                query  viral_final  \
# 0  Европа делает "самоубийственное движение", ког...     0.468767
# 1  Верховный суд Ингушетии отправил под арест быв...     0.428130
# 2  Свыше миллиона детей пойдут в первый класс в э...     0.456934
# 3  ❗️Бывший президент Сирии Башар Асад накануне с...     0.666604
# 4  Сегодня на рынке жилья сложилась патовая ситуа...     0.746281
#
#                                              llm_raw  \
# 0  {\n  "is_economic": false,\n  "topic": null,\n...
# 1  {\n  "is_economic": false,\n  "topic": null,\n...
# 2  {\n  "is_economic": false,\n  "topic": null,\n...
# 3  {\n  "is_economic": false,\n  "topic": null,\n...
# 4  {\n  "is_economic": true,\n  "topic": "Макроэк...
#
#                                             llm_json
# 0  {'confidence': 0.96, 'economic_signals': [], '...
# 1  {'confidence': 0.9, 'economic_signals': [], 'e...
# 2  {'confidence': 0.95, 'economic_signals': [], '...
# 3  {'confidence': 0.95, 'economic_signals': [], '...
# 4  {'confidence': 0.95, 'economic_signals': ['зав...

# %%
labeled_df.to_csv("labeled_posts.csv")

# %%
import json
import pandas as pd

labeled_df = labeled_df.drop(columns=['llm_raw'], errors='ignore')

def parse_llm_json(x):
    if pd.isna(x):
        return {}
    if isinstance(x, dict):
        return x
    if isinstance(x, str):
        x = x.strip()
        if not x:
            return {}
        try:
            return json.loads(x)
        except Exception:
            return {}
    return {}

parsed = labeled_df['llm_json'].apply(parse_llm_json)

labeled_df['is_economic'] = parsed.apply(lambda d: d.get('is_economic'))
labeled_df['topic'] = parsed.apply(lambda d: d.get('topic'))
labeled_df['confidence'] = parsed.apply(lambda d: d.get('confidence'))
labeled_df['reason'] = parsed.apply(lambda d: d.get('reason'))
labeled_df['economic_signals'] = parsed.apply(lambda d: d.get('economic_signals'))
labeled_df['noise_signals'] = parsed.apply(lambda d: d.get('noise_signals'))

labeled_df['economic_signals'] = labeled_df['economic_signals'].apply(
    lambda x: ", ".join(x) if isinstance(x, list) else None
)
labeled_df['noise_signals'] = labeled_df['noise_signals'].apply(
    lambda x: ", ".join(x) if isinstance(x, list) else None
)
labeled_df = labeled_df.rename(columns={'query':"message"})

# %%
labeled_df.to_csv("labeled_posts_full.csv")

# %%
import pandas as pd

labeled_df = pd.read_csv("labeled_posts_full.csv")
# Out:
# /tmp/ipykernel_339/1050790247.py:3: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   labeled_df = pd.read_csv("labeled_posts_full.csv")

# %%
labeled_df.head()
# Out:
#    Unnamed: 0  ... noise_signals
# 0           0  ...           NaN
# 1           1  ...           NaN
# 2           2  ...           NaN
# 3           3  ...           NaN
# 4           4  ...           NaN
#
# [5 rows x 12 columns]

# %%
labeled_df["is_economic"].value_counts()
# Out:
# is_economic
# False    35962
# True     31292
# Name: count, dtype: int64

# %%
labeled_df[labeled_df["is_economic"]==True]["topic"].value_counts()
# Out:
# topic
# Государственная экономическая политика    9040
# Корпоративные финансы                     4572
# Макроэкономика                            3978
# Санкции и геополитика                     3582
# Рынки капитала                            3169
# Сырьевые рынки                            2114
# Международная торговля                    1825
# Другое                                    1608
# Валютный рынок                            1400
# Сырьевые рынры                               3
# Сырьевые рын рынки                           1
# Name: count, dtype: int64

# %%
import pandas as pd
labeled_df = pd.read_csv("labeled_posts_full.csv")
# Out:
# /tmp/ipykernel_345/2898943466.py:2: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   labeled_df = pd.read_csv("labeled_posts_full.csv")

# %%
labeled_df.columns
# Out:
# Index(['Unnamed: 0', 'message_id', 'id_channel', 'message', 'viral_final',
#        'llm_json', 'is_economic', 'topic', 'confidence', 'reason',
#        'economic_signals', 'noise_signals'],
#       dtype='object')

# %%
economic = labeled_df[labeled_df["is_economic"] == True][["message_id", "id_channel", "message", "viral_final", "is_economic", "topic", "confidence", "reason"]]

# %%
economic.head()
# Out:
#                              message_id  id_channel  \
# 4  0006e10d-39d5-48fd-b5d8-3fbc732d09f4           6
# 5  0007e2f8-787d-404f-91ff-e2582096a4a7          18
# 6  000884a5-8291-4ec1-805f-ac131112aaf7           6
# 7  000a6ee0-13d8-4b05-8200-67d9fd3725d0           4
# 8  000b0331-92a9-4eb4-9f58-d00811257758          18
#
#                                              message  viral_final is_economic  \
# 4  Сегодня на рынке жилья сложилась патовая ситуа...     0.746281        True
# 5  Сербия согласна поддержать санкции Евросоюза п...     0.542513        True
# 6  Китайский рынок акций упал сильнее всего с апр...     0.588634        True
# 7  Переход к банкингу будущего может принести стр...     0.362871        True
# 8  Министерство труда США отменило рекомендации 2...     0.422529        True
#
#                                     topic  confidence  \
# 4                          Макроэкономика        0.95
# 5                   Санкции и геополитика        0.96
# 6                          Рынки капитала        0.96
# 7                                  Другое        0.96
# 8  Государственная экономическая политика        0.95
#
#                                               reason
# 4  Новость описывает состояние рынка жилья, цены,...
# 5  Новость посвящена позиции Сербии по санкциям Е...
# 6  Новость описывает падение фондового рынка и ра...
# 7  Текст описывает финансовый сектор и потенциаль...
# 8  Новость описывает изменение регулятивных реком...

# %%
economic["topic"] = economic["topic"].replace({
    "Сырьевые рын рынки": "Сырьевые рынки",
    "Сырьевые рынры": "Сырьевые рынки",
})

# %%
economic["topic"].value_counts()
# Out:
# topic
# Государственная экономическая политика    9040
# Корпоративные финансы                     4572
# Макроэкономика                            3978
# Санкции и геополитика                     3582
# Рынки капитала                            3169
# Сырьевые рынки                            2118
# Международная торговля                    1825
# Другое                                    1608
# Валютный рынок                            1400
# Name: count, dtype: int64
